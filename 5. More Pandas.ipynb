# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color: #301E40; border: 0px; -moz-border-radius: 10px; -webkit-border-radius: 10px;">
# <br/><br/>
# <h1 style="font-size: 45px; color: white; align: center;"><center>
# <img src="https://raw.githubusercontent.com/HumbleData/beginners-data-workshop/master/media/humble-data-logo-white-transparent.png" width="250px" /><br/><br/>
# Plus de pandas
# </center></h1>
# </div>

# %% [markdown]
# ***Remarque*** : ce notebook contient des cellules de solution avec ***une*** solution. Souviens‑toi qu’il n’y a pas qu’une seule solution à un problème !
#
# Tu reconnaîtras ces cellules car elles commencent par **# %**.
#
# Si tu veux voir la solution, tu devras enlever le **#** (tu peux le faire avec **Ctrl** + **?**) puis exécuter la cellule. Si tu veux exécuter le code de la solution, tu devras exécuter la cellule à nouveau.

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Exercice
# </h2><br>
# </div>

# %% [markdown]
# > 1. Importe pandas (avec la convention la plus utilisée vue dans le notebook 2).
# > 2. Importe datetime.
# > 3. Importe matplotlib (comme montré dans le notebook 3.1).
# > 4. Ajoute la commande magique pour afficher les graphiques dans Jupyter.

# %%
# !cat solutions/05_01.py

# %% [markdown]
# Dans ce notebook, nous allons utiliser des données fournies par le [gouvernement du Royaume‑Uni](https://data.gov.uk/dataset/a59198d9-2e24-4816-be1b-c3a1efa02dda/better-training-for-safer-food). Elles sont publiées sous la [Open Government Licence](http://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/).

# %% [markdown]
# >Charge les données de l’année 2014 et assigne‑les à df_2014 (chemin : 'data/food_training/training_2014.csv')

# %%
# !cat solutions/05_02.py

# %% [markdown]
# >Regarde les premières lignes de df_2014

# %%
# !cat solutions/05_03.py

# %% [markdown]
# Tu peux voir que les en‑têtes ne sont pas au bon endroit.
# Si tu regardes la documentation, tu verras que le paramètre *header* de la méthode read_csv est réglé sur *infer*. Il va déduire l’en‑tête en utilisant la première ligne (qui a l’index *0*).

# %% [markdown]
# >Charge les données de l’année 2104 en utilisant le paramètre header et assigne‑les à df_2014 (il sera écrasé)

# %%
# !cat solutions/05_04.py

# %% [markdown]
# >Regarde les premières lignes de df_2014. Ça a l’air mieux, non ?

# %%
# !cat solutions/05_05.py

# %% [markdown]
# >Charge les données pour les années 2015 et 2016 et assigne‑les à df_2015 et df_2016 (n’oublie pas le paramètre !)

# %%
# !cat solutions/05_06.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Concaténer
# </h2><br>
# </div>

# %% [markdown]
# pandas a une excellente page de documentation sur le [merge, join et la concaténation](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html).

# %% [markdown]
# >En t’appuyant sur la documentation, concatène les 3 DataFrames en un seul, nommé df.

# %%
# !cat solutions/05_07.py

# %% [markdown]
# >Vérifie la shape de df

# %%
# !cat solutions/05_08.py

# %% [markdown]
# >Regarde les index de df en utilisant l’attribut index.

# %%
# !cat solutions/05_09.py

# %% [markdown]
# On voit que l’index ne va pas de 0 à 265 avec un pas de 1...
# > Supprime l’index existant et réinitialise‑le en utilisant la méthode ***reset_index***.
# > Vérifie l’index de df.

# %%
# !cat solutions/05_10.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Supprimer des colonnes
# </h2><br>
# </div>

# %% [markdown]
# >Affiche les informations relatives aux colonnes de df.

# %%
# !cat solutions/05_11.py

# %% [markdown]
# On voit que les deux dernières colonnes sont complètement vides, donc on va les supprimer.

# %% [markdown]
# >Affiche l’aide (help) de la méthode drop (si tu préfères, tu peux chercher la documentation sur internet).

# %%
# !cat solutions/05_12.py

# %% [markdown]
# Tu peux voir que la valeur par défaut de *axis* est *0*. Dans ce cas, la méthode regardera les lignes (c.-à-d. *axis 0*) du DataFrame.
# Dans notre cas, on veut supprimer des colonnes (c.-à-d. *axis 1*).

# %% [markdown]
# >Supprime les deux dernières colonnes de df.
# >labels : fournis une liste avec les noms des colonnes
# >N’oublie pas l’axe !

# %%
# !cat solutions/05_13.py

# %%
df.head()

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Données textuelles
# </h2><br>
# </div>

# %% [markdown]
# Pour [travailler avec des données textuelles](https://pandas.pydata.org/pandas-docs/version/0.23.4/text.html), on devra utiliser l’attribut ***str*** pour accéder aux méthodes (par ex. df['col'].str.replace('-', ' ')).
# On devra utiliser cet attribut dans différents cas, mais avant ça, regardons la colonne Location.
# >Affiche les valeurs uniques de la colonne Location.

# %%
# !cat solutions/05_14.py

# %% [markdown]
# Tu peux voir que les villes et pays sont séparés par un point‑virgule (même si certaines valeurs sont manquantes). Nous allons découper la colonne ***Location***.
# >Essaie de découper la colonne ***Location*** sur le point‑virgule.
# >Tu peux consulter le [lien](https://pandas.pydata.org/pandas-docs/version/0.23.4/text.html) donné plus haut ou la [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).

# %%
# !cat solutions/05_15.py

# %% [markdown]
# Cela renvoie une liste avec les éléments qui étaient avant et après le point‑virgule.
# >Réessaie de découper la colonne ***Location***, mais cette fois étends (expand) les résultats pour les obtenir dans des colonnes séparées.

# %%
# !cat solutions/05_16.py

# %% [markdown]
# >Crée des colonnes ***city*** et ***country*** dans df en utilisant ce découpage.

# %%
# !cat solutions/05_17.py

# %% [markdown]
# >Supprime la colonne ***Location***.

# %%
# !cat solutions/05_18.py

# %%
df.head()

# %% [markdown]
# >Obtiens le nombre de valeurs uniques dans la colonne ***country***.

# %%
# !cat solutions/05_19.py

# %% [markdown]
# >Vérifie le décompte de chaque valeur unique dans la colonne ***country***.

# %%
# !cat solutions/05_20.py

# %% [markdown]
# On voit que certains pays (par ex. Italy) semblent apparaître plusieurs fois avec des variantes.
# >Utilise la méthode strip pour enlever les espaces (potentiels) au début et à la fin des villes et des pays.

# %%
# !cat solutions/05_21.py

# %% [markdown]
#    >Vérifie à nouveau le nombre de valeurs uniques dans la colonne country

# %%
# !cat solutions/05_22.py

# %% [markdown]
# >Regarde les lignes où le ***country*** est Portugal.
# Que remarques‑tu à propos de la ***city*** ?

# %%
# !cat solutions/05_23.py

# %% [markdown]
# >Mets la colonne ***city*** en minuscules (n’oublie pas de la ré‑assigner à la colonne **city**).

# %%
# !cat solutions/05_24.py

# %% [markdown]
# >Regarde les lignes où la ***city*** contient ' ***/*** '.

# %%
# !cat solutions/05_25.py

# %% [markdown]
# Décidons que nous ne voulons avoir qu’une seule ville par ligne. On va garder uniquement la ville avant le slash (« / »).
# >Remplace la chaîne contenant un slash (c.-à-d. ***/***) par la ville apparaissant avant le slash dans la colonne ***city***.
# >Tu devras utiliser une [expression régulière](https://docs.python.org/3/howto/regex.html#repeating-things).
# >Tu peux tester ton expression régulière [ici](https://regex101.com).

# %%
# !cat ../solutions/05_26.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Map (mapping)
# </h2><br>
# </div>

# %%
df['country'].value_counts()

# %% [markdown]
# On a vu que certain·e·s pays étaient renseigné·e·s par leur code et d’autres par leur nom. On va tout harmoniser dans le même format.
# On peut le faire en appliquant (mapping) un dictionnaire à une colonne. Cela remplacera la ***clé*** par la ***valeur*** correspondante.
# >Complète le code ci‑dessous pour remplacer les codes pays par le nom du pays.
# >Remarque : on utilise un masque car on veut remplacer seulement certaines valeurs de la série.

# %%
dict_code = {'BG':'Bulgaria', 'CZ':'Czech Republic', 'IT':'Italy', 'GR':'Greece', 'SI':'Slovenia', 'UK':'United Kingdom'}

df.loc[df['country'].isin(dict_codes.keys()), 'country'] =

# %%
# !cat ../solutions/05_27.py

# %%
df['country'].value_counts(dropna=False)

# %% [markdown]
# Certaines valeurs de ville sont inconnues.
# >Regarde les valeurs de ***country*** là où la ***city*** est ***unknown***.

# %%
df['city'].value_counts()

# %%
# !cat ../solutions/05_28.py

# %% [markdown]
# >Complète le code ci‑dessous pour remplacer la valeur ***unknown*** dans la colonne ***city*** par la capitale du ***country*** correspondant.

# %%
dict_capitals = {'Denmark':'copenhague', 'France':'paris', 'Italy':'rome', 'Spain':'madrid', 'United Kingdom':'london'}

df.loc[df['city'] == 'unknown', 'city'] = df.loc[df['city'] == 'unknown', 'country'].

# %%
# !cat ../solutions/05_29.py

# %% [markdown]
# Beaucoup de pays sont manquants, mais on peut les renseigner en utilisant les villes.
# On peut créer un dictionnaire des villes et de leur pays correspondant à partir des lignes où ***country*** n’est pas nul.

# %%
dict_cities = df.loc[df['country'].notnull(), ['city', 'country']].set_index('city').to_dict()['country']

# %% [markdown]
# On veut maintenant vérifier si toutes les villes dont on a besoin sont dans notre dictionnaire.
# >En soustrayant les clés du dictionnaire à l’ensemble des valeurs de ***city***, trouve quelles villes sont dans la colonne ***city*** mais pas dans les ***keys*** du dictionnaire.

# %%
# !cat ../solutions/05_30.py

# %% [markdown]
# >En sachant que Bristol est au Royaume‑Uni, Gothenburg en Suède, Graz en Autriche, Lyon en France, Murcia en Espagne et Parma en Italie, ajoute quelques paires clé‑valeur au dictionnaire ***dict_cities***.
# >Tu peux soit ajouter chaque paire clé‑valeur individuellement, soit [mettre à jour](https://python-reference.readthedocs.io/en/latest/docs/dict/update.html) dict_cities avec un autre dictionnaire.

# %%
# !cat ../solutions/05_31.py

# %% [markdown]
# >Utilise ce dictionnaire pour remplir certains pays manquants.

# %%
# !cat ../solutions/05_32.py

# %% [markdown]
# >Obtiens le décompte des différentes valeurs de la colonne ***country***, en affichant les valeurs NaN.

# %%
# !cat ../solutions/05_33.py

# %% [markdown]
# On peut voir qu’il n’y a que 4 valeurs NaN. Elles correspondent à de mauvaises saisies que l’on pourrait corriger « manuellement ». N’hésite pas à ajouter quelques lignes ci‑dessous pour essayer si tu en as envie !

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Appliquer
# </h2><br>
# </div>

# %% [markdown]
# >Écris une fonction qui renvoie ***single*** si la valeur passée est 1, et ***multiple*** sinon.

# %%
# !cat ../solutions/05_34.py

# %% [markdown]
# >Applique cette fonction à la colonne ***Attendees***.

# %%
# !cat ../solutions/05_35.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Jointure
# </h2><br>
# </div>

# %% [markdown]
# >Charge les données de langue et assigne‑les à languages (chemin : 'data/food_training/languages.csv')

# %%
# !cat ../solutions/05_36.py

# %%
languages.head()

# %% [markdown]
# >Fais une jointure entre df et languages pour ajouter l’information de langue à df.
# >Tu peux consulter la page sur le [merge, join et la concaténation](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html) ou la [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html) de la méthode merge.

# %%
# !cat ../solutions/05_37.py

# %% [markdown]
# >Supprime la colonne ***Country*** de df.

# %%
# !cat ../solutions/05_38.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Date et heure
# </h2><br>
# </div>

# %% [markdown]
# >Vérifie le dtype de ***DateFrom***.

# %%
# !cat ../solutions/05_39.py

# %% [markdown]
# ***DateFrom*** et ***DateTo*** sont des objets (object).
# >Convertis ces deux colonnes au format ***datetime***.

# %%
# !cat ../solutions/05_40.py

# %% [markdown]
# Remarque : on aurait pu utiliser le paramètre *parse_dates* lors du chargement des données.
# On peut maintenant utiliser ces colonnes pour filtrer ou faire des calculs.
# >Affiche les lignes où la formation a commencé après le 1er février 2017.

# %%
# !cat ../solutions/05_41.py

# %% [markdown]
# >Crée une colonne ***duration*** avec la durée de la formation.

# %%
# !cat ../solutions/05_42.py

# %% [markdown]
# >Crée une colonne ***month*** indiquant le mois de début de la formation.
# >Trace un histogramme de la colonne ***month***.

# %%
# !cat ../solutions/05_43.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Trier des valeurs
# </h2><br>
# </div>

# %% [markdown]
# >Trie df par ordre alphabétique des ***cities***.

# %%
# !cat ../solutions/05_44.py

# %% [markdown]
# >Trie df par ***duration*** croissante et par nombre d’***Attendees*** décroissant.

# %%
# !cat ../solutions/05_45.py

# %% [markdown]
# On voit qu’il y a eu quelques soucis de saisie des dates...

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Regrouper (groupby)
# </h2><br>
# </div>

# %% [markdown]
# >Regroupe df par ***city***. Assigne les données groupées à df_gr.

# %%
# !cat ../solutions/05_46.py

# %% [markdown]
# >Obtiens la moyenne du nombre d’***Attendees*** pour les données groupées.

# %%
# !cat ../solutions/05_47.py

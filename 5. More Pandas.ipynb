# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color: #301E40; border: 0px; -moz-border-radius: 10px; -webkit-border-radius: 10px;">
# <br/><br/>
# <h1 style="font-size: 45px; color: white; align: center;"><center>
# <img src="https://raw.githubusercontent.com/HumbleData/beginners-data-workshop/master/media/humble-data-logo-white-transparent.png" width="250px" /><br/><br/>
# 판다스 더 알아보기
# </center></h1>
# </div>

# %% [markdown]
# ***주의***: 이 노트북에는 예시 해답이 들어 있는 셀이 포함되어 있습니다. 한 문제에 정답이 하나만 있는 것은 아니라는 점을 기억하세요!
#
# 이런 셀은 **# %** 로 시작하는 것으로 알아볼 수 있어요.
#
# 해답을 보고 싶다면 **#** 을 지우고(**Ctrl + /** 등으로 토글 가능) 셀을 실행하세요. 해답 코드를 실제로 실행하려면 셀을 한 번 더 실행해야 합니다.

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# 연습 문제
# </h2><br>
# </div>

# %% [markdown]
# > 1. pandas를 임포트하세요(노트북 2에서 주로 사용한 관례대로).
# > 2. datetime을 임포트하세요.
# > 3. matplotlib을 임포트하세요(노트북 3.1처럼).
# > 4. 주피터에서 플롯이 보이도록 매직 커맨드를 추가하세요.

# %%
# !cat solutions/05_01.py

# %% [markdown]
# 이 노트북에서는 [영국 정부(UK government)](https://data.gov.uk/dataset/a59198d9-2e24-4816-be1b-c3a1efa02dda/better-training-for-safer-food)에서 제공한 데이터를 사용할 것입니다. 이 데이터는 [Open Government Licence](http://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/) 하에 제공됩니다.

# %% [markdown]
# >2014년 데이터를 불러와 df_2014에 할당하세요 (경로: 'data/food_training/training_2014.csv')

# %%
# !cat solutions/05_02.py

# %% [markdown]
# >df_2014의 처음 몇 행을 확인해 보세요

# %%
# !cat solutions/05_03.py

# %% [markdown]
# 헤더가 올바른 위치에 있지 않다는 것을 알 수 있습니다.
# 문서를 확인해 보면, read_csv 메서드의 *header* 매개변수가 기본적으로 *infer* 로 설정되어 있음을 볼 수 있습니다. 이는 첫 번째 행(인덱스가 *0* 인 행)을 사용해 헤더를 추론합니다.

# %% [markdown]
# >read_csv의 header 매개변수를 사용해 2014년 데이터를 다시 불러와 df_2014에 할당하세요(기존 값을 덮어씁니다)

# %%
# !cat solutions/05_04.py

# %% [markdown]
# >df_2014의 처음 몇 행을 다시 확인해 보세요. 더 좋아 보이지 않나요?

# %%
# !cat solutions/05_05.py

# %% [markdown]
# >2015년과 2016년 데이터를 불러와 각각 df_2015, df_2016에 할당하세요(해당 매개변수 설정을 잊지 마세요!)

# %%
# !cat solutions/05_06.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# 연결(Concatenate)
# </h2><br>
# </div>

# %% [markdown]
# pandas에는 [merge, join, concatenation](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)에 대한 좋은 문서가 있습니다.

# %% [markdown]
# >문서를 참고하여 세 개의 데이터프레임을 하나로 이어 붙여 df를 만드세요.

# %%
# !cat solutions/05_07.py

# %% [markdown]
# >df의 shape를 확인해 보세요

# %%
# !cat solutions/05_08.py

# %% [markdown]
# >index 속성을 사용해 df의 인덱스를 확인해 보세요.

# %%
# !cat solutions/05_09.py

# %% [markdown]
# 인덱스가 0부터 265까지 1씩 증가하는 연속 값이 아님을 알 수 있습니다...
# > 기존 인덱스를 지우고 ***reset_index*** 메서드로 다시 설정하세요.
# > 그런 다음 df의 인덱스를 확인해 보세요.

# %%
# !cat solutions/05_10.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# 열 삭제하기
# </h2><br>
# </div>

# %% [markdown]
# >df의 열 정보(columns 관련 정보)를 표시하세요.

# %%
# !cat solutions/05_11.py

# %% [markdown]
# 마지막 두 개의 열이 완전히 비어 있으므로 삭제하겠습니다.

# %% [markdown]
# >drop 메서드의 도움말을 확인하세요(원한다면 인터넷에서 문서를 검색해도 됩니다).

# %%
# !cat solutions/05_12.py

# %% [markdown]
# 기본적으로 *axis*의 값은 *0* 입니다. 이 경우 메서드는 데이터프레임의 행을 기준으로 동작합니다(즉, *axis 0*).
# 우리의 경우에는 열을 삭제해야 하므로(즉, *axis 1*) 축을 1로 지정해야 합니다.
#
# >df의 마지막 두 개 열을 삭제하세요.
# >labels: 삭제할 열 이름들의 리스트를 전달하세요
# >axis도 잊지 마세요!

# %%
# !cat solutions/05_13.py

# %%
df.head()

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# 텍스트 데이터
# </h2><br>
# </div>

# %% [markdown]
# [텍스트 데이터를 다루려면](https://pandas.pydata.org/pandas-docs/version/0.23.4/text.html) 메서드에 접근하기 위해 ***str*** 속성을 사용해야 합니다(예: df['col'].str.replace('-', ' ')).
# 이 속성은 여러 경우에 사용하게 될 텐데, 그 전에 먼저 Location 열을 살펴보겠습니다.
# >Location 열의 고유값을 표시하세요.

# %%
# !cat solutions/05_14.py

# %% [markdown]
# 도시와 국가가 세미콜론(;)으로 구분되어 있음을 볼 수 있습니다(값이 일부 비어 있는 경우도 있음). 이제 ***Location*** 열을 분할해 보겠습니다.
# >***Location*** 열을 세미콜론을 기준으로 분할해 보세요.
# >앞서 제공한 [링크](https://pandas.pydata.org/pandas-docs/version/0.23.4/text.html)나 [문서](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html)를 참고하세요.

# %%
# !cat solutions/05_15.py

# %% [markdown]
# 이는 세미콜론 앞과 뒤의 항목을 리스트로 반환합니다.
# >***Location*** 열을 다시 분할하되, 결과를 확장(expand)하여 서로 다른 열로 나오도록 설정하세요.

# %%
# !cat solutions/05_16.py

# %% [markdown]
# >이 분할 결과를 사용하여 df에 ***city*** 와 ***country*** 열을 만드세요.

# %%
# !cat solutions/05_17.py

# %% [markdown]
# >***Location*** 열을 삭제하세요.

# %%
# !cat solutions/05_18.py

# %%
df.head()

# %% [markdown]
# >***country*** 열의 고유값 개수를 구하세요.

# %%
# !cat solutions/05_19.py

# %% [markdown]
# >***country*** 열의 각 고유값 개수를 확인하세요.

# %%
# !cat solutions/05_20.py

# %% [markdown]
# 일부 국가명(예: Italy)이 여러 형태로 중복되어 나타나는 것을 볼 수 있습니다.
# >도시와 국가 문자열의 앞뒤에 있는 불필요한 공백을 제거하기 위해 strip 메서드를 사용하세요.

# %%
# !cat solutions/05_21.py

# %% [markdown]
#    >country 열의 고유값 개수를 다시 확인하세요

# %%
# !cat solutions/05_22.py

# %% [markdown]
# >***country*** 가 Portugal인 행들을 살펴보세요.
# ***city*** 에서는 무엇을 발견할 수 있나요?

# %%
# !cat solutions/05_23.py

# %% [markdown]
# >***city*** 열의 값을 모두 소문자(lower case)로 바꾸세요(변경 결과를 다시 **city** 열에 재할당하는 것을 잊지 마세요).

# %%
# !cat solutions/05_24.py

# %% [markdown]
# >***city*** 에 ' ***/*** ' 가 포함된 행들을 살펴보세요.

# %%
# !cat solutions/05_25.py

# %% [markdown]
# 각 행마다 도시를 하나만 두기로 합시다. 슬래시 앞의 도시만 남기겠습니다.
# >***city*** 열에서 슬래시(예: ***/***)가 포함된 문자열을 슬래시 앞에 나타나는 도시로 대체하세요.
# >이를 위해 [정규식](https://docs.python.org/3/howto/regex.html#repeating-things)을 사용해야 합니다.
# >[여기](https://regex101.com)에서 정규식을 테스트할 수 있습니다.

# %%
# !cat ../solutions/05_26.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# 맵(Map)
# </h2><br>
# </div>

# %%
df['country'].value_counts()

# %% [markdown]
# 일부 국가는 국가 코드로, 다른 것들은 전체 이름으로 입력되어 있음을 확인했습니다. 이제 형식을 모두 동일하게 통일하겠습니다.
# 이를 위해 열에 딕셔너리를 매핑할 수 있습니다. 그러면 해당 ***키(key)*** 가 일치하는 ***값(value)*** 으로 바뀝니다.
# >아래 코드를 완성하여 국가 코드를 국가 이름으로 바꾸세요.
# >시리즈의 특정 값들만 바꾸기 위해 마스크를 사용한다는 점에 유의하세요.

# %%
dict_code = {'BG':'Bulgaria', 'CZ':'Czech Republic', 'IT':'Italy', 'GR':'Greece', 'SI':'Slovenia', 'UK':'United Kingdom'}

df.loc[df['country'].isin(dict_codes.keys()), 'country'] =

# %%
# !cat ../solutions/05_27.py

# %%
df['country'].value_counts(dropna=False)

# %% [markdown]
# 일부 도시(city) 값은 unknown입니다.
# >***city*** 가 ***unknown*** 인 행들의 ***country*** 값을 살펴보세요.

# %%
df['city'].value_counts()

# %%
# !cat ../solutions/05_28.py

# %% [markdown]
# >***city*** 열에서 값이 ***unknown*** 인 항목을 해당 ***country*** 의 수도로 바꾸도록 아래 코드를 완성하세요.

# %%
dict_capitals = {'Denmark':'copenhague', 'France':'paris', 'Italy':'rome', 'Spain':'madrid', 'United Kingdom':'london'}

df.loc[df['city'] == 'unknown', 'city'] = df.loc[df['city'] == 'unknown', 'country'].

# %%
# !cat ../solutions/05_29.py

# %% [markdown]
# 많은 국가 값이 비어 있지만, 도시 정보를 사용해 채울 수 있습니다.
# ***country*** 가 null이 아닌 행들로부터 도시와 해당 국가의 매핑 딕셔너리를 만들 수 있습니다.

# %%
dict_cities = df.loc[df['country'].notnull(), ['city', 'country']].set_index('city').to_dict()['country']

# %% [markdown]
# 이제 필요한 모든 도시가 우리 딕셔너리에 있는지 확인해 봅시다.
# >딕셔너리의 키 집합을 ***city*** 값들의 집합에서 빼서, ***city*** 열에는 있지만 딕셔너리 ***keys*** 에는 없는 도시들이 무엇인지 찾으세요.

# %%
# !cat ../solutions/05_30.py

# %% [markdown]
# >Bristol은 영국(United Kingdom), Gothenburg는 스웨덴, Graz는 오스트리아, Lyon은 프랑스, Murcia는 스페인, Parma는 이탈리아에 있습니다. 이 정보를 바탕으로 ***dict_cities*** 딕셔너리에 키-값 쌍을 추가하세요.
# >각 항목을 하나씩 추가해도 되고, 다른 딕셔너리로 [update](https://python-reference.readthedocs.io/en/latest/docs/dict/update.html) 해서 한 번에 추가해도 됩니다.

# %%
# !cat ../solutions/05_31.py

# %% [markdown]
# >이 딕셔너리를 사용하여 비어 있는 country 값을 일부 채우세요.

# %%
# !cat ../solutions/05_32.py

# %% [markdown]
# >NaN 값을 포함하여 ***country*** 열의 서로 다른 값들의 개수를 구하세요.

# %%
# !cat ../solutions/05_33.py

# %% [markdown]
# NaN 값은 4개뿐임을 확인할 수 있습니다. 이는 잘못 입력된 데이터에 해당하며, 원한다면 아래에 몇 줄 더 추가해 수동으로 수정해 볼 수도 있습니다.

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# 적용(Apply)
# </h2><br>
# </div>

# %% [markdown]
# >전달된 값이 1이면 ***single*** 을, 그렇지 않으면 ***multiple*** 을 반환하는 함수를 작성하세요.

# %%
# !cat ../solutions/05_34.py

# %% [markdown]
# >이 함수를 ***Attendees*** 열에 적용하세요.

# %%
# !cat ../solutions/05_35.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# 조인(Join)
# </h2><br>
# </div>

# %% [markdown]
# >언어 데이터(language data)를 불러와 languages 변수에 할당하세요 (경로: 'data/food_training/languages.csv')

# %%
# !cat ../solutions/05_36.py

# %%
languages.head()

# %% [markdown]
# >df와 languages를 조인하여 언어 정보(language)를 df에 추가하세요.
# >[merge, join, concatenation](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html) 페이지나 merge 메서드 [문서](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html)를 참고할 수 있습니다.

# %%
# !cat ../solutions/05_37.py

# %% [markdown]
# >df에서 ***Country*** 열을 삭제하세요.

# %%
# !cat ../solutions/05_38.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# 날짜/시간(Date time)
# </h2><br>
# </div>

# %% [markdown]
# >***DateFrom*** 의 dtype을 확인하세요.

# %%
# !cat ../solutions/05_39.py

# %% [markdown]
# ***DateFrom*** 과 ***DateTo*** 는 object 타입입니다.
# >이 두 열을 ***datetime*** 형식으로 변환하세요.

# %%
# !cat ../solutions/05_40.py

# %% [markdown]
# 참고: 데이터를 불러올 때 *parse_dates* 매개변수를 사용할 수도 있었습니다.
# 이제 이 열들을 이용해 필터링하거나 계산을 수행할 수 있습니다.
# >2017년 2월 1일 이후에 시작한 교육 행만 표시하세요.

# %%
# !cat ../solutions/05_41.py

# %% [markdown]
# >훈련 기간(duration)을 나타내는 ***duration*** 열을 생성하세요.

# %%
# !cat ../solutions/05_42.py

# %% [markdown]
# >훈련이 시작된 월(month)을 나타내는 ***month*** 열을 생성하세요.
# >***month*** 열의 히스토그램을 그리세요.

# %%
# !cat ../solutions/05_43.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# 값 정렬(Sorting values)
# </h2><br>
# </div>

# %% [markdown]
# >***cities*** 를 알파벳순으로 정렬하여 df를 정렬하세요.

# %%
# !cat ../solutions/05_44.py

# %% [markdown]
# >***duration*** 은 오름차순, ***Attendees*** 수는 내림차순으로 df를 정렬하세요.

# %%
# !cat ../solutions/05_45.py

# %% [markdown]
# 날짜 입력과 관련해 몇 가지 문제가 있었음을 확인할 수 있습니다...

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# 그룹화(Group By)
# </h2><br>
# </div>

# %% [markdown]
# >df를 ***city*** 로 그룹화하세요. 그룹화한 결과를 df_gr 변수에 할당하세요.

# %%
# !cat ../solutions/05_46.py

# %% [markdown]
# >그룹화한 데이터에서 ***Attendees*** 의 평균을 구하세요.

# %%
# !cat ../solutions/05_47.py

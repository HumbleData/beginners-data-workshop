# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color: #301E40; border: 0px; -moz-border-radius: 10px; -webkit-border-radius: 10px;">
# <br/><br/>
# <h1 style="font-size: 45px; color: white; align: center;"><center>
# <img src="https://raw.githubusercontent.com/HumbleData/beginners-data-workshop/master/media/humble-data-logo-white-transparent.png" width="250px" /><br/><br/>
# Introduction à Python
# </center></h1>
# </div>

# %% [markdown]
# ## Bienvenue à l'apprentissage de Python !
#
# Ces notebooks contiennent un mélange de texte et de code. Cela te permet d'expérimenter facilement avec du code et de garder la documentation comme celle-ci au même endroit. Un autre avantage de ces notebooks est que tu peux exécuter chaque cellule individuellement et donc travailler de manière incrémentale avec ton code. Si tu veux exécuter une cellule, tu peux appuyer sur le bouton "►" ci‑dessus lorsque tu as sélectionné la cellule. Alternativement, tu peux appuyer sur **Shift + Enter** pour exécuter et passer à la cellule suivante ou bien **Ctrl + Enter** (Windows) ou **Cmd + Enter** (Mac).
#
# Nous allons te guider à travers différents aspects du langage Python de manière interactive. Prends ton temps pour expérimenter si tu le souhaites et n'hésite pas à poser des questions ou à chercher sur Google. L'une des premières leçons en programmation est l'utilisation de la documentation et des informations partagées par d'autres programmeur·euse·s. Jupyter a une autre astuce : tu peux placer ton curseur dans les parenthèses d'un appel de fonction comme `print()` et appuyer sur **Shift + Tab**. Cela te permettra de voir la documentation d'une fonction directement dans le notebook (*astuce pro* : tu peux appuyer jusqu'à quatre fois pour différents effets).
#
# Concernant Python lui‑même, l'une de ses grandes forces est son extensibilité. Il possède une quantité surprenante de fonctionnalités directement dans le langage de base, cependant, tu peux `importer` presque n'importe quel code que d'autres rendent disponible sous forme de bibliothèques. Ci‑dessous, tu peux voir une importation spéciale qui te montre le "Zen of Python", un ensemble de principes qui pourraient guider ton parcours de programmation.

# %%
# Nous pouvons utiliser des commentaires pour documenter notre code dans une cellule de code
import this  # Zen of Python

# %% [markdown]
# **--> Simple est mieux que complexe.**
# Il est très facile d'afficher ***Hello World*** en Python :

# %%
print('Hello World!')

# %% [markdown]
# **PEP 8** est le guide de style de Python. Vous pouvez le trouver ici :
# https://www.python.org/dev/peps/pep-0008/
#
# C'est bon à connaître, mais lorsque vous deviendrez un·e programmeur·euse professionnel·le, il existe des programmes appelés « linter » qui vous aideront à respecter PEP 8.

# %% [markdown]
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Variables
# </h2><br>
# </div>

# %% [markdown]
# En programmation, il est très utile de stocker des valeurs. Accéder à des valeurs via des noms s'appelle une variable. Python est très convivial, car il vous permet de stocker la plupart des choses dans une variable, sans réserver explicitement de l'espace mémoire. De plus, les ordinateurs doivent différencier les types de données, par exemple `5` est un entier et `'Hello'` est une chaîne de caractères, mais Python essaie de gérer cela de manière intuitive pour vous. Vous apprendrez les différents types dans les sections suivantes !
#
# **Python est un langage de programmation orienté objet. Vous n'avez pas besoin de déclarer les variables (ou leurs types) avant de les utiliser car chaque variable en Python est un objet.**

# %%
name = 'Sandrine'

# %%
print(name)

# %% [markdown]
# De plus, les variables peuvent être facilement mises à jour. Essayez ci-dessous !
# ---
#
# ***Remarque*** : lorsque vous voyez des cellules qui commencent par `# !cat`, cela signifie que c'est une cellule qui peut vous donner ***une*** solution. N'oubliez pas qu'il peut y avoir plusieurs solutions à un problème en programmation !
#
# Si vous souhaitez voir la solution, vous devrez enlever le `#` avec **Ctrl + /** (Windows) ou **Cmd + /** (macOS) puis exécuter la cellule.
#
# Essayez d'abord de résoudre par vous-même avant de regarder la solution.
#
#
# ---

# %% [markdown]
# >Affectez une autre chaîne à la variable 'name' et affichez cette variable

# %%
|

# %%
# !cat solutions/01_01.py

# %% [markdown]
# **!!! Une variable peut changer de type lorsqu'elle est réaffectée.**

# %% [markdown]
# >Affectez un nombre (sans guillemets) à la variable 'name' et affichez cette variable

# %%
# !cat solutions/01_02.py

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Chaînes de caractères
# </h2><br>
# </div>

# %% [markdown]
# Une chaîne commence et se termine toujours par des guillemets simples ( ' ) ou doubles ( \" ). Il n'y a pas de différence, sauf s'il y a une apostrophe ( ' ) à l'intérieur de la chaîne.

# %%
'Beginners Data Workshop'

# %%
"Beginner's Data Workshop"

# %% [markdown]
# >Écrivez *Je profite de cet atelier !* en utilisant d'abord des guillemets doubles, puis des guillemets simples.

# %%
# double quotes

# %%
# !cat solutions/01_03.py

# %%
# single quotes

# %%
# !cat solutions/01_04.py

# %% [markdown]
# **Oh non, une erreur !** Les erreurs ne sont pas effrayantes. Pense-les comme des messages amicaux qui t’aident à comprendre ce qui s’est mal passé. Voici comment les lire :
# - Lis les erreurs à l’envers, donc commence par le bas ! C’est une "SyntaxError", ce qui signifie qu’il y a quelque chose qui cloche dans notre code Python.
# - Il y a une petite flèche `^` qui pointe vers ce qui a posé problème. Quelque chose près du m de `I'm`
# - Sur la ligne du haut, il est indiqué que l’erreur est à la "ligne 2". C’est souvent utile pour corriger (ou "debugger") du code cassé.
#
# **En fait, si tu veux utiliser des guillemets simples à l’intérieur de guillemets simples, tu dois « échapper » l’apostrophe avec un backslash ( \\ ).**
#
# >Essayons ça !

# %%
# Guillemets simples, deuxième essai

# %%
# !cat solutions/01_05.py

# %% [markdown]
# Comme mentionné plus tôt, Python essaie de tout gérer de la façon la plus intuitive possible. Cela signifie que les chaînes peuvent être ajoutées (concaténées) entre elles.

# %%
'Nous sommes ' + ' partout dans le monde.'

# %% [markdown]
# De plus, les chaînes peuvent même être multipliées par un nombre.

# %%
'Génial! 🎉' * 3

# %%
'😂' * 50

# %% [markdown]
# On peut accéder à des parties de chaînes en utilisant un « slice » (découpage). Un caractère d’une chaîne (considéré par Python comme une chaîne de longueur 1) s’obtient avec un slice, et une sous‑chaîne avec une plage de slice. Point important à noter :
#
# **!!! Comme pour les anniversaires, Python commence à compter à partir de 0 ! (on dit qu’il est « zero‑indexed »)**
#
# (Si ça t’intéresse de savoir pourquoi, voici une [lettre historique de Dijkstra](https://www.cs.utexas.edu/users/EWD/transcriptions/EWD08xx/EWD831.html) à ce sujet.)

# %%
s = 'I am a Pythonista.'

# %% [markdown]
# ***Slice***
# On peut accéder aux caractères d’une chaîne en référant leur position (numéro d’« index ») entre crochets.

# %%
# Sélectionner le premier caractère de la chaîne s.
s[0]

# %% [markdown]
# > Sélectionne le dernier caractère de la chaîne s

# %%
# !cat solutions/01_06.py

# %% [markdown]
# ***Plage de slice***
# On peut obtenir une plage de caractères d’une chaîne en utilisant une plage de slice.

# %%
# Sélectionner, dans la chaîne s, depuis la position 2 jusqu’à (mais sans inclure) la position 6.
s[2:6]  # 6 est exclu.

# %% [markdown]
# On peut omettre le nombre de début (resp. de fin) `s[:6]`. Dans ce cas, ça commence à l’index 0 (resp. ça se termine au plus grand index).

# %% [markdown]
# > Sélectionne les 3 derniers caractères de la chaîne s

# %%
# !cat solutions/01_07.py

# %% [markdown]
# On peut vérifier si une chaîne contient une autre chaîne (une « substring »), en utilisant *in* et *not in*.
#
# **!!! Python est sensible à la casse ! La chaîne `'a'` n’est pas égale à `'A'`***

# %%
# Vérifier si s contient 'python'
print(s)
'python' in s

# %% [markdown]
# > Vérifie que s ne contient pas 'I' (I majuscule)

# %%
# !cat solutions/01_08.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Nombres
# </h2><br>
# </div>

# %% [markdown]
# Python a différents types numériques. Deux d’entre eux sont utilisés plus souvent que les autres :
# - **Integers (entiers) :** des nombres sans décimales, p. ex. `1`, `2`, `-5`
# - **Floats (nombres à virgule flottante) :** des nombres avec un point décimal, p. ex. `3.14158`, `2.5`, `0.1` et même `3.0`.
#
# Python essaie de gérer ces nombres de manière intuitive quand on mélange des entiers et des floats.

# %% [markdown]
# ### Opérateurs de base

# %% [markdown]
# **Addition :**
# > Essaie d’additionner deux nombres.

# %%
# !cat solutions/01_09.py

# %% [markdown]
# **Soustraction :**
# > Essaie de soustraire deux nombres.

# %%
# !cat solutions/01_10.py

# %% [markdown]
# **Multiplication :**
# Le signe pour la multiplication est *.
# > Essaie de multiplier deux nombres.

# %%
# !cat solutions/01_11.py

# %% [markdown]
# **Exposant :**
# Le signe pour l’exposant (la puissance) est *`**`*.
#
# > Essaie la puissance d’un entier.

# %%
# !cat solutions/01_12.py

# %% [markdown]
# > Essaie la puissance d’un float

# %%
# !cat solutions/01_13.py

# %% [markdown]
# > Essaie la puissance d’un entier écrit comme un float (par ex. 12.0)

# %%
# !cat solutions/01_14.py

# %% [markdown]
# **Division et modulo**
# - Le signe de la division est **`/`**.
# - Le signe de la division entière (floor division) est **`//`**. Elle renvoie le « quotient » d’une division — le nombre de fois qu’un nombre « entre » dans un autre. (« Si une boîte contient six œufs et qu’on a 99 œufs, combien de boîtes peut‑on remplir ? »)
# - Le signe **`%`** est le [modulo](https://en.wikipedia.org/wiki/Modulo_operation), qui renvoie le « reste » après la division.

# %% [markdown]
# > Divise 6 par 2

# %%
# !cat solutions/01_15.py

# %% [markdown]
# > Essaie la division entière de 6 par 2

# %%
# !cat solutions/01_16.py

# %% [markdown]
# > Divise 19 par 5

# %%
# !cat solutions/01_17.py

# %% [markdown]
# *Remarque* : la division renvoie un float.

# %% [markdown]
# **La division entière renvoie un int, la partie non fractionnaire.**
# > Essaie la division entière de 19 par 5

# %%
# !cat solutions/01_18.py

# %% [markdown]
# **Le modulo renvoie le reste de la division**

# %% [markdown]
# > Calcule 19 modulo 5

# %%
# !cat solutions/01_19.py

# %% [markdown]
# **--> 19 = 3 * 5 + 4**

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Ordre des opérations
# </h2><br>
# </div>

# %% [markdown]
# L'ordre des opérations en Python respecte les règles habituelles des mathématiques (parenthèses -> puissances -> division/multiplication -> addition/soustraction). **En cas de doute, utilise des parenthèses** pour rendre clair (pour toi, et pour toute personne qui lira ton code) ce que tu veux faire.

# %%
5 + 6 * 10

# %%
(5 + 6) * 10

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Booléens
# </h2><br>
# </div>

# %% [markdown]
# Les booléens sont les deux valeurs constantes `True` et `False`. La valeur numérique de `True` est `1` et celle de `False` est `0`. Ces valeurs sont très importantes pour les comparaisons, donc on va aussi apprendre un nouvel opérateur :
#
# **`==`** est un opérateur d’égalité, différent de **`=`** qui est l’opérateur d’affectation que tu as utilisé pour assigner des variables.

# %%
True == 1  # '==' est un opérateur d’égalité, différent de '=' qui est un opérateur d’affectation.

# %%
False * 3

# %% [markdown]
# En utilisant **`!=`**, vérifie que `False` n’est pas égal à `2`.

# %%
# !cat solutions/01_20.py

# %% [markdown]
# > Vérifie si la longueur de ton prénom est supérieure à 8.

# %%
# !cat solutions/01_21.py

# %% [markdown]
# On peut utiliser les opérateurs `and` et `or` avec les booléens en Python. Tape-les ci‑dessous et observe la couleur du texte qui change, car Python reconnaît ces mots-clés ! On peut les utiliser pour chaîner plusieurs comparaisons. Ils suivent la logique mathématique.
#
# | A     | B     | A and B | A or B |
# | :---  | :---  | :---    | :---   |
# | True  | True  | True    | True   |
# | True  | False | False   | True   |
# | False | True  | False   | True   |
# | False | False | False   | False  |
#
# > Vérifie si la longueur de ton prénom est supérieure à 5 et si la longueur du prénom de ton·ta mentor est inférieure à 7.

# %%
# !cat solutions/01_22.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Listes
# </h2><br>
# </div>

# %% [markdown]
# Une liste est une suite de valeurs séparées par des virgules, entre crochets.
#
# Les éléments d’une liste peuvent avoir des types différents.

# %%
list_greeting = ['Hallo', 'Bonjour', 10, 'Hello', 'Ciao', False]

# %% [markdown]
# On peut accéder à une seule valeur avec un slice, et à plusieurs valeurs avec une plage de slice. Consulte la section « découpage de chaînes » ci‑dessus pour t’y référer.

# %% [markdown]
# > Récupère le premier élément de la liste.

# %%
# !cat solutions/01_23.py

# %% [markdown]
# Récupère tous les éléments de la liste à partir du 4e.
#
# Remarque : il n’est pas nécessaire de mettre un nombre après les deux points quand on veut sélectionner jusqu’à la fin de la liste.

# %% [markdown]
# > Récupère les éléments à partir de celui d’index 3 jusqu’à la fin de la liste.

# %%
# !cat solutions/01_24.py

# %% [markdown]
# **Récupère les éléments de la liste jusqu’au 4e.**

# %% [markdown]
# > Récupère les éléments depuis le début de la liste jusqu’à la valeur d’index 4 (l’index 4 est exclu).

# %%
# !cat solutions/01_25.py

# %% [markdown]
# **Le découpage avancé (advanced slicing) nous permet de définir comment l’index de la liste s’incrémente entre les index de début et de fin que l’on sélectionne.**
# La syntaxe du découpage ressemble alors à ceci : [début:fin:pas]
# Par exemple, si on veut sélectionner un élément sur trois d’une liste, on fixera le pas à 3.

# %% [markdown]
# > Récupère un élément sur deux dans la liste des salutations

# %%
# !cat solutions/01_26.py

# %% [markdown]
# **On peut mettre à jour une liste en ré‑assignant une valeur sélectionnée via un slice.**
# Par exemple, on peut remplacer False par 'Ave' dans list_greeting.

# %%
list_greeting[-1] = 'Ave'
print(list_greeting)

# %% [markdown]
# > Remplace 10 par Hola dans list_greeting, puis affiche list_greeting pour vérifier.

# %%
# !cat solutions/01_27.py

# %% [markdown]
# On peut avoir des listes à l’intérieur d’une liste, on parle souvent de « listes imbriquées » :

# %%
list_of_lists = [[1, 2, 3], [4, 5]]

# %%
list_of_lists[0]  # Accéder au premier élément de la liste, qui est lui-même une liste.

# %%
list_of_lists[0][-1]  # Accéder au dernier élément de la première liste.

# %% [markdown]
# On peut concaténer des listes avec ' + '.

# %%
[1, 2, 3] + [4, 5, 6]

# %% [markdown]
# On peut aussi utiliser la multiplication pour répéter des valeurs dans une liste (ne fonctionne qu’avec des entiers).

# %%
['Hey'] * 5

# %% [markdown]
# On peut aussi utiliser `in` / `not in` avec les listes.

# %% [markdown]
# > Vérifie si `10` est dans `list_greeting`.

# %%
# !cat solutions/01_28.py

# %% [markdown]
# > Vérifie que 'Ole' n’est pas dans list_greeting.

# %%
# !cat solutions/01_29.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Fonctions intégrées
# </h2><br>
# </div>

# %% [markdown]
# Tu as vu ta première fonction au tout début de ce notebook, c’est‑à‑dire `print("Hello World")`. Les fonctions sont un moyen d’écrire du code réutilisable. Dans ce cas, `print()` est la façon dont Python affiche une sortie que tu fournis. Cependant, Python vient avec plein d’autres fonctions utiles, fournies par la bibliothèque standard, par d’autres bibliothèques, ou écrites par toi‑même pour éviter de répéter du code.
#
# Les fonctions toujours disponibles en Python se trouvent ici :
# https://docs.python.org/3/library/functions.html

# %% [markdown]
# >Affiche *'Nous y sommes !'*.

# %%
# !cat solutions/01_30.py

# %% [markdown]
# >Calcule la longueur de la variable chaîne `snakes`.

# %%
snakes = "🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍"

# %%
# !cat solutions/01_31.py

# %% [markdown]
# >Calcule la longueur de list_greeting.

# %%
# !cat solutions/01_32.py

# %% [markdown]
# >Détermine le maximum de 1, 2, 3, 4 et 5.

# %%
# !cat solutions/01_33.py

# %% [markdown]
# >Arrondis le nombre 123.45 à l’entier le plus proche.

# %%
# !cat solutions/01_34.py

# %% [markdown]
# >Arrondis le nombre 123.45 à 1 chiffre après la virgule.

# %%
# !cat solutions/01_35.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Méthodes
# </h2><br>
# </div>

# %% [markdown]
# Une méthode est une fonction associée à un objet. En gros, c’est une façon pour un objet d’exposer des fonctions qui agissent sur lui-même.
#
# Par exemple, on peut changer la chaîne `s` en majuscules en utilisant la méthode `.upper()`.

# %%
s.upper()

# %% [markdown]
# >En utilisant la méthode append, ajoute 'Aloha' à list_greeting.

# %%
# !cat solutions/01_36.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Importer des modules
# </h2><br>
# </div>

# %% [markdown]
# On peut importer des modules (du code Python qui peut définir des fonctions, des classes et des variables).
#
# En général, on écrit tous les imports au début d’un programme Python ou d’un notebook.

# %% [markdown]
# **Petit avertissement**
# Assure-toi de faire confiance aux packages que tu installes !
#
# Demande-toi :
# 1. Qui a écrit ce code ?
# 2. Est‑ce que je fais confiance à ce code pour avoir accès à mon ordinateur ?
# 3. `pip install` peut être un peu plus dangereux : n’importe qui peut téléverser un package sur le Python Package Index ("PyPI"), d’où `pip` installe. Sois très vigilant·e, car la moindre faute de frappe peut devenir un risque de sécurité !
# 4. `conda install` est un environnement plus « fermé » et donc mieux adapté à un usage en entreprise.

# %% [markdown]
# > Depuis la bibliothèque **math**, importe **sqrt** pour calculer la racine carrée de **24 336**.

# %%
# !cat solutions/01_37.py

# %% [markdown]
# Les programmeur·euse·s Python sont vraiment paresseux·ses ! (Ou obsédé·e·s par la productivité, à toi de choisir !)
#
# Du coup, tu peux définir des alias pour les imports. Écrire `as np` ne fait que deux caractères, alors que `numpy` en fait cinq. C’est moins à taper quand tu écris de longs programmes.
#
# > Importe `numpy as np` et essaie **`np.sin(np.pi/4)`**.

# %%
# !cat solutions/01_38.py

# %% [markdown]
# ---
#
# # 🎉 Félicitations, tu es arrivé·e à la fin du Notebook 1 ! 🎉
# Prends une pause bien méritée, prépare‑toi une boisson réconfortante de ton choix ou va prendre un petit encas. Tu peux même partager une photo de ton encas/boisson dans le canal #random — on adore voir des photos de tout le monde aux quatre coins du monde. ☕️
#
# ![](https://media0.giphy.com/media/3otPoS81loriI9sO8o/200.gif)

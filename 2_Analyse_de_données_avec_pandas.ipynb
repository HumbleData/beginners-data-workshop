# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color: #301E40; border: 0px; -moz-border-radius: 10px; -webkit-border-radius: 10px;">
# <br/><br/>
# <h1 style="font-size: 45px; color: white; align: center;"><center>
# <img src="https://raw.githubusercontent.com/HumbleData/beginners-data-workshop/master/media/humble-data-logo-white-transparent.png" width="250px" /><br/><br/>
# Analyse de données avec pandas
# </center></h1>
# </div>

# %% [markdown]
# > ***Remarque*** : ce notebook contient des cellules de solution avec ***une*** solution. Souviens-toi qu'il n'y a pas qu'une seule solution à un problème !
# >
# > Tu reconnaîtras ces cellules car elles commencent par **# %**.
# >
# > Si tu veux voir la solution, tu devras enlever le **#** (tu peux le faire avec **Ctrl** + **?**) puis exécuter la cellule. Si tu veux exécuter le code de la solution, tu devras exécuter la cellule à nouveau.

# %% [markdown]
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Packages d'analyse de données
# </h2><br>
# </div>

# %% [markdown]
# Les Data Scientists utilisent une grande variété de bibliothèques en Python qui rendent le travail avec les données beaucoup plus simple. Ces bibliothèques comprennent principalement :
#
# | Package | Description |
# | -- | -- |
# | `NumPy` | Calculs numériques — fait tout le « heavy lifting » en s’appuyant sur des sous‑programmes en C. Tu bénéficies donc à la fois de la productivité de Python et de la puissance de calcul de C. Le meilleur des deux mondes ! |
# | `SciPy` | Calcul scientifique, tests statistiques et bien plus encore ! |
# | `pandas` | Le couteau suisse de la manipulation de données. Tu verras probablement pandas dans toute démo PyData ! pandas est construit au‑dessus de NumPy, donc c’est **rapide**. |
# | `matplotlib` | Un package de visualisation de données ancien mais puissant, inspiré de Matlab. |
# | `Seaborn` | Un package de visualisation plus récent et facile à utiliser (mais plus limité), construit au‑dessus de matplotlib. |
# | `scikit-learn` | Ta boutique « machine learning » tout‑en‑un ! Classification, régression, clustering, réduction de dimension et plus encore. |
# | `nltk` et `spacy` | nltk = « natural language processing » toolkit ; spacy est un package plus récent pour le traitement du langage naturel et très facile à utiliser. |
# | `statsmodels` | Tests statistiques, prévision de séries temporelles et plus. L’interface « model formula » sera familière aux personnes venant de R. |
# | `requests` et `Beautiful Soup` | `requests` + `Beautiful Soup` = super combinaison pour créer des web scrapers. |
# | `Jupyter` | Jupyter est aussi un package. Regarde la dernière version sur https://pypi.org/project/jupyter/ et mets à jour par ex. avec `conda install jupyter==1.0.0` |
#
# Bien qu’il en existe d’innombrables autres.
#
# Aujourd’hui, on va surtout se concentrer sur la bibliothèque qui représente 99 % de notre travail : `pandas`. pandas est construit sur la vitesse et la puissance de NumPy.

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Imports
# </h2><br>
# </div>

# %%
import pandas as pd

# %% [markdown]
# >Importe numpy en utilisant la convention vue à la fin du premier notebook.

# %%
# !cat solutions/02_01.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Chargement des données
# </h2><br>
# </div>

# %% [markdown]
# Pour voir la documentation d’une méthode, tu peux utiliser la fonction help. Dans Jupyter, tu peux aussi mettre un point d’interrogation avant la méthode.

# %%
# ?pd.read_csv

# %% [markdown]
# Pour charger le DataFrame que nous utilisons dans ce notebook, on va fournir le chemin du fichier : ../data/Penguins/penguins.csv

# %% [markdown]
# >Charge le fichier, lis‑le dans un DataFrame pandas et assigne‑le à df

# %%
# !cat solutions/02_02.py

# %% [markdown]
# **Pour jeter un coup d’œil aux 5 premières lignes de df, on peut utiliser la méthode *head*.**

# %%
df.head()

# %% [markdown]
# >Regarde les 3 dernières lignes de df en utilisant la méthode tail

# %%
# !cat solutions/02_03.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Informations générales sur le jeu de données
# </h2><br>
# </div>

# %% [markdown]
# **Pour obtenir la taille du dataset, on peut utiliser l’attribut *shape*.**
# Le premier nombre est le nombre de lignes, le second est le nombre de colonnes

# %% [markdown]
# >Affiche la shape de df (ne mets pas de parenthèses à la fin)

# %%
# !cat solutions/02_04.py

# %% [markdown]
# >Récupère les noms des colonnes et des infos à leur sujet (nombre de non‑nuls et type) en utilisant la méthode info.

# %%
# !cat solutions/02_05.py

# %% [markdown]
# >Récupère les colonnes du DataFrame en utilisant l’attribut columns.

# %%
# !cat solutions/02_06.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Paramètres d’affichage
# </h2><br>
# </div>

# %% [markdown]
# On peut vérifier l’option d’affichage du notebook.

# %%
pd.options.display.max_rows

# %% [markdown]
# >Force pandas à afficher 25 lignes en changeant la valeur ci‑dessus.

# %%
# !cat solutions/02_07.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Créer des sous‑ensembles de données
# </h2><br>
# </div>

# %% [markdown]
# On peut créer un sous‑ensemble d’un DataFrame par étiquette (label), par index ou une combinaison des deux.
# Il y a différentes manières de le faire, en utilisant .loc, .iloc et aussi [].
# Voir la [documentation](https://pandas.pydata.org/pandas-docs/stable/indexing.html).

# %% [markdown]
# >Affiche la colonne 'bill_length_mm'

# %%
# !cat solutions/02_08.py

# %% [markdown]
# *Remarque :* On pourrait aussi utiliser `df.bill_length_mm`, mais ce n’est pas la meilleure idée car cela peut se confondre avec des méthodes et ne fonctionne pas pour les colonnes avec des espaces.

# %% [markdown]
# >Regarde la 12e observation :

# %%
# Utilisation de .iloc (utilise des positions, le "i" signifie entier "integer").

# %%
# !cat solutions/02_09.py

# %%
# Utilisation de .loc (utilise les index et les labels).

# %%
# !cat solutions/02_10.py

# %% [markdown]
# >Affiche le **bill_length_mm** des trois dernières observations.

# %%
# using .iloc

# %%
# !cat solutions/02_11.py

# %%
# using .loc

# %%
# !cat solutions/02_12.py

# %% [markdown]
# Et enfin, regarde le **flipper_length_mm** et le **body_mass_g** des 146e, 8e et 1re observations :

# %%
# using .iloc

# %%
# !cat solutions/02_13.py

# %%
# using .loc

# %%
# !cat solutions/02_14.py

# %% [markdown]
# **!!ATTENTION!!**  Contrairement à Python et à ``.iloc``, la valeur de fin dans une plage spécifiée par ``.loc`` **inclut** le dernier index indiqué.

# %%
df.iloc[5:10]

# %%
df.loc[5:10]

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Filtrer des données avec des conditions
# </h2><br>
# </div>

# %% [markdown]
# **On peut aussi utiliser des conditions pour filtrer.**
# On veut afficher les lignes de df où **body_mass_g** est supérieur à 4000. On va commencer par créer un masque avec cette condition.

# %%
mask_PW = df['body_mass_g'] > 4000
mask_PW

# %% [markdown]
# Remarque : cela renvoie des booléens. Si on passe ce masque à notre DataFrame, il n’affichera que les lignes où le masque vaut True.

# %%
df[mask_PW]

# %% [markdown]
# >Affiche les lignes de df où **body_mass_g** est supérieur à 4000 et **flipper_length_mm** est inférieur à 185.

# %%
# !cat solutions/02_15.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Valeurs
# </h2><br>
# </div>

# %% [markdown]
# On peut obtenir le nombre de valeurs uniques d’une colonne donnée en utilisant la méthode `nunique`.
#
# Par exemple, on peut obtenir le nombre de valeurs uniques de la colonne species :

# %%
df['species'].nunique()

# %% [markdown]
# On peut aussi obtenir la liste des valeurs uniques d’une colonne avec la méthode `unique`.
# >Renvoie la liste des valeurs uniques de la colonne species

# %%
# !cat solutions/02_16.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Valeurs nulles et NaN
# </h2><br>
# </div>

# %% [markdown]
# Quand tu travailles avec des données, tu apprendras vite que les données ne sont jamais « propres ». Ces valeurs sont généralement appelées valeurs nulles. En calcul, c’est une bonne pratique de définir un « nombre spécial » qui est « **N**ot **a** **N**umber », aussi appelé NaN.
#
# On peut utiliser la méthode `isnull` pour savoir si une valeur est nulle ou non. Elle renvoie des booléens.

# %%
df['flipper_length_mm'].isnull()

# %% [markdown]
# **On peut enchaîner différentes méthodes.**
# Par exemple, on peut appliquer la méthode `sum` après la méthode `isnull` pour connaître le nombre d’observations nulles dans la colonne **flipper_length_mm**.
# >Obtiens le nombre total de valeurs nulles pour **flipper_length_mm**.

# %%
# !cat solutions/02_17.py

# %% [markdown]
# Pour obtenir le décompte des différentes valeurs d’une colonne, on peut utiliser la méthode `value_counts`.
#
# Par exemple, pour la colonne species :

# %%
df['species'].value_counts()

# %% [markdown]
# Si on veut connaître le décompte des valeurs NaN, on doit passer la valeur `False` au paramètre **dropna** (réglé à `True` par défaut).
# > Renvoie la proportion pour chaque sexe, en incluant les valeurs NaN.

# %%
# !cat solutions/02_18.py

# %% [markdown]
# Pour obtenir la proportion au lieu du décompte de ces valeurs, on doit passer la valeur `True` au paramètre **normalize**.
# >Renvoie la proportion pour chaque species.

# %%
# !cat solutions/02_19.py

# %% [markdown]
# >En utilisant l’attribut index, récupère les index des observations sans **flipper_length_mm**

# %%
# !cat solutions/02_20.py

# %% [markdown]
# Utilise la méthode **[dropna](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html)** pour enlever la ligne qui n’a que des valeurs NaN.
# >Affiche l’aide (help) de la méthode dropna.

# %%
# !cat solutions/02_21.py

# %% [markdown]
# >Utilise la méthode dropna pour supprimer la ligne de `df` où toutes les valeurs sont NaN, et assigne le résultat à `df_2`.

# %%
# !cat solutions/02_22.py

# %% [markdown]
# On peut utiliser une f-string pour formater une chaîne. Il faut écrire un `f` avant le guillemet et mettre ce que tu veux formater entre accolades.

# %%
print(f'shape of df: {df.shape}')

# %% [markdown]
# > Affiche le nombre de lignes de `df_2` en utilisant une f-string. A-t-on perdu des lignes entre `df` et `df_2` ? Si non, pourquoi ?

# %%
# !cat solutions/02_23.py

# %% [markdown]
# >Utilise la méthode dropna pour supprimer les lignes de `df_2` qui contiennent au moins une valeur NaN, et assigne le résultat à `df_3`

# %%
# !cat solutions/02_24.py

# %% [markdown]
# > Affiche le nombre de lignes de `df_3` en utilisant une f-string.

# %%
# !cat solutions/02_25.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Doublons
# </h2><br>
# </div>

# %% [markdown]
# >Supprime les lignes en double de `df_3` et assigne le nouveau DataFrame à `df_4`

# %%
# !cat solutions/02_26.py

# %%
# Vérifier la forme de df_4
df_4.shape

# %% [markdown]
# Tu devrais voir que 4 lignes ont été supprimées.

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Quelques statistiques
# </h2><br>
# </div>

# %% [markdown]
# >Utilise la méthode describe pour voir comment les données sont distribuées (seulement les variables numériques !)

# %%
# !cat solutions/02_27.py

# %% [markdown]
# On peut aussi changer le type de la colonne **species** pour économiser de la mémoire. Remarque : tu peux recevoir un **SettingWithCopyWarning** — tu peux l’ignorer en toute sécurité dans ce notebook.

# %%
df_4['species'] = df_4['species'].astype('category')

# %% [markdown]
# >En utilisant l’attribut dtypes, vérifie les types des colonnes de `df_4`

# %%
# !cat solutions/02_28.py

# %% [markdown]
# On peut aussi utiliser les fonctions count(), mean(), sum(), median(), std(), min() et max() séparément si on ne s’intéresse qu’à l’une d’entre elles.

# %% [markdown]
# >Obtiens le minimum pour chaque colonne numérique de `df_4`

# %%
# !cat solutions/02_29.py

# %% [markdown]
# >Calcule le maximum de **flipper_length_mm**

# %%
# !cat solutions/02_30.py

# %% [markdown]
# On peut aussi obtenir des informations pour chaque espèce en utilisant la méthode `groupby`.
#
#
# > Obtiens la médiane pour chaque **species**.

# %%
# !cat solutions/02_31.py

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Enregistrer le DataFrame en fichier CSV
# </h2><br>
# </div>

# %% [markdown]
# >Sauvegarde `df_4` en utilisant ce chemin : `'data/Penguins/my_penguins.csv'`

# %%
# !cat solutions/02_32.py
